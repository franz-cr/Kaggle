# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install ntscraper

# %%
from ntscraper import Nitter# as nt

strTwitterQuery = '(to:RoblesBarrantes) lang:es until:2024-02-01 since:2024-01-01'

# %%
ntNitterInstance = Nitter()
# Out:
# Testing instances: 100%|██████████| 32/32 [00:51<00:00,  1.62s/it]

# %%
def get_tweets(hashtag, mode, size):
    tweets = ntNitterInstance.get_tweets(hashtag, mode = mode, number = size)
    final_tweets = []
    
    # Parse the dictionary and saves as a list of attributes
    for tweet in tweets['tweets']:
        data = [tweet['link'], tweet['text'], tweet['date'], tweet['stats']['likes'], tweet['stats']['comments']]
        final_tweets.append(data)
    
    # Saves list as a Pandas DataFrame
    dfTweetData = pd.DataFrame(final_tweets, columns = ['link', 'text', 'date', 'Likes', 'Comments'])
    return dfTweetData

# %%
dicTweetsFA = ntNitterInstance.get_tweets("ariel",mode="term",number=10,
                                            #since="2024-02-01",until="2024-02-05",
                                            language="es",to="RoblesBarrantes"
                                            )

print(len(dicTweetsFA))
# Out:
# 2

# %%
dicTweetsFA
# Out:
# {'tweets': [{'link': 'https://twitter.com/lidcruzi29/status/1754909909232062914#m',
#    'text': 'Excelente don Ariel. Todo lo que sea en beneficio de los habitantes es bueno.',
#    'user': {'name': 'Lidiette Cruz',
#     'username': '@lidcruzi29',
#     'profile_id': '1508652303686975492',
#     'avatar': 'https://pbs.twimg.com/profile_images/1508652303686975492/HsEdCH3G_bigger.jpg'},
#    'date': 'Feb 6, 2024 · 4:48 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': ['@RoblesBarrantes'],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 0, 'quotes': 0, 'likes': 0},
#    'pictures': [],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/MinorMurilloRu1/status/1754849430149206059#m',
#    'text': 'Men don Ariel lo felicito por su valentía hay que estar bien pijiado para seguir publicando tanta pendejada sabiendo que us es tan despreciado y solo kk recibe',
# ...

# %% [markdown]
# ## Prensa Canalla Analysis

# %%
dicTweetsPrensaCanalla = ntNitterInstance.get_tweets("prensacanalla",
                                                     mode="hashtag",
                                                     number=100,
                                                     since="2024-02-01",
                                                     #until="2024-02-05",
                                                     language="es",
                                                     to="crhoycom")

dicTweetsPrensaCanalla
# Out:
# {'tweets': [{'link': 'https://twitter.com/Arantesdo1/status/1754580925436809326#m',
#    'text': 'Dejen a ese inútil tranquilo en ese puesto. Necesitamos que siga enterrando al narco PLN. #PrensaCanalla',
#    'user': {'name': 'Arantesdo',
#     'username': '@Arantesdo1',
#     'profile_id': '1410400164066598917',
#     'avatar': 'https://pbs.twimg.com/profile_images/1410400164066598917/k-Zpv3LH_bigger.jpg'},
#    'date': 'Feb 5, 2024 · 7:01 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': ['@crhoycom'],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 0, 'quotes': 0, 'likes': 0},
#    'pictures': [],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/Arantesdo1/status/1754516416940704198#m',
# ...

# %%
lstTweetsPrensaCanalla = []

for tweet in dicTweetsPrensaCanalla['tweets']:
    lstTweetExtract = [tweet['link'], 
                       tweet['text'], 
                       tweet['date'], 
                       tweet['stats']['likes'], 
                       tweet['stats']['comments'],
                       tweet['stats']['retweets']
                      ]
    lstTweetsPrensaCanalla.append(lstTweetExtract)

print(lstTweetsPrensaCanalla)
# Out:
# [['https://twitter.com/Arantesdo1/status/1754580925436809326#m', 'Dejen a ese inútil tranquilo en ese puesto. Necesitamos que siga enterrando al narco PLN. #PrensaCanalla', 'Feb 5, 2024 · 7:01 PM UTC', 0, 0, 0], ['https://twitter.com/Arantesdo1/status/1754516416940704198#m', 'Porque nunca antes se había desenmascarado a la mafia que dirige el TSE. Ahora queda claro el porqué Antonio Sobrado se marchó sin aparente causa de ese Tribunal. Simplemente no quería quedar expuesto en los fraudes que planeó esa institución para ayudar al PLN. #PrensaCanalla', 'Feb 5, 2024 · 2:44 PM UTC', 1, 0, 0], ['https://twitter.com/Arantesdo1/status/1754378425668616565#m', '¿Y cuándo se ha visto que un fraude sea difícil? El éxito del estafador radica en hacer la trampa atractiva y muy sencilla para que cualquier incauto caiga. #PrensaCanalla', 'Feb 5, 2024 · 5:36 AM UTC', 0, 0, 0], ['https://twitter.com/Arantesdo1/status/1754194141125202047#m', '¿Y cuándo se ha visto que un fraude sea difícil? El éxito d
# ...

# %%
dfTweetsPrensaCanalla = pd.DataFrame(lstTweetsPrensaCanalla, 
                                     columns = ['link','text','date','Likes','Comments','Retweets'])

dfTweetsPrensaCanalla
# Out:
#                                                  link  \
# 0   https://twitter.com/Arantesdo1/status/17545809...
# 1   https://twitter.com/Arantesdo1/status/17545164...
# 2   https://twitter.com/Arantesdo1/status/17543784...
# 3   https://twitter.com/Arantesdo1/status/17541941...
# 4   https://twitter.com/Arantesdo1/status/17541911...
# 5   https://twitter.com/Arantesdo1/status/17534668...
# 6   https://twitter.com/Arantesdo1/status/17534466...
# 7   https://twitter.com/Arantesdo1/status/17534447...
# 8   https://twitter.com/Arantesdo1/status/17534427...
# 9   https://twitter.com/Arantesdo1/status/17530366...
# 10  https://twitter.com/Arantesdo1/status/17529217...
#
#                                                  text  \
# 0   Dejen a ese inútil tranquilo en ese puesto. Ne...
# 1   Porque nunca antes se había desenmascarado a l...
# 2   ¿Y cuándo se ha visto que un fraude sea difíci...
# 3   ¿Y cuándo se ha visto que un fraude sea difíci...
# ...

# %%
dfTweetsPrensaCanalla.to_csv('Prensa_Canalla_Tweets_CR_Hoy.csv',index=False)

# %%
dicTweetsTest = ntNitterInstance.get_tweets("Apple",mode="hashtag",number=10)

print(len(dicTweetsTest))

# %%
#dicTweets = ntNitterInstance.get_random_instance()

# %%
#print(len(dicTweets))
#print(dicTweets)
# Out:
# 34
# https://nitter.us.projectsegfau.lt

# %%
final_tweets = []

for tweet in dicTweets['tweets']:
    data = [tweet['link'], tweet['text'], tweet['date'], tweet['stats']['likes'], tweet['stats']['comments']]
    final_tweets.append(data)

print(final_tweets)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 data = [tweet['link'], tweet['text'], tweet['date'], tweet['stats']['likes'], tweet['stats']['comments']]
#       2 final_tweets.append(data)
#
# NameError: name 'tweet' is not defined

# %%
data = get_tweets("Apple", "hashtag", 5)
data
# Out:
# Empty DataFrame
# Columns: [link, text, date, Likes, Comments]
# Index: []

# %%
data = get_tweets("FraudeAmplio", "hashtag", 5)
data
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data = get_tweets("FraudeAmplio", "hashtag", 5)
#       2 data
#
# Cell In[6], line 2, in get_tweets(hashtag, mode, size)
#       1 def get_tweets(hashtag, mode, size):
# ----> 2     tweets = ntScraperInstance.get_tweets(hashtag, mode = mode, number = size)
#       3     final_tweets = []
#       5     for tweet in tweets['tweets']:
#
# File /opt/conda/lib/python3.10/site-packages/ntscraper/nitter.py:896, in Nitter.get_tweets(self, terms, mode, number, since, until, near, language, to, filters, exclude, max_retries, instance)
#     893 if type(terms) == str:
#     894     term = terms.strip()
# --> 896     return self._search(
#     897         term,
#     898         mode,
#     899         number,
#     900         since,
#     901         until,
#     902         near,
#     903         language,
# ...

# %%
tweets = ntScraperInstance.get_tweets("RoblesBarrantes", mode = "user", number = size)
final_tweets = []

for tweet in tweets['tweets']:
    data = [tweet['link'], tweet['text'], tweet['date'], tweet['stats']['likes'], tweet['stats']['comments']]
    final_tweets.append(data)

data = pd.DataFrame(final_tweets, columns = ['link', 'text', 'date', 'Likes', 'Comments'])

data

# %%
#!pip install pysentimiento
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 4.3 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.2/251.2 kB 11.0 MB/s eta 0:00:00
# ...
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171033 sha256=20e2c251e93461481fe84bb048b9d3770ba4150b83235e4e6a885b284a294754
#   Stored in directory: /root/.cache/pip/wheels/31/8a/8c/315c9e5d7773f74b33d5ed33f075b49c6eaeb7cedbb86e2cf8
# Successfully built emoji
# ...
#   Attempting uninstall: emoji
#     Found existing installation: emoji 2.10.0
#     Uninstalling emoji-2.10.0:
#       Successfully uninstalled emoji-2.10.0
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.26.1
#     Uninstalling accelerate-0.26.1:
#       Successfully uninstalled accelerate-0.26.1
# ...

# %%
from pysentimiento import create_analyzer
# Out:
# 2024-02-06 01:26:26.649520: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-06 01:26:26.649667: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-06 01:26:26.825042: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
analyzer = create_analyzer(task="sentiment", lang="es")

analyzer.predict("Qué gran jugador es Messi")
# Out:
# config.json:   0%|          | 0.00/925 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/435M [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# tokenizer_config.json:   0%|          | 0.00/384 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.31M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/167 [00:00<?, ?B/s]
# AnalyzerOutput(output=POS, probas={POS: 0.946, NEU: 0.037, NEG: 0.017})

# %%
analyzer.predict("Un diputado que le da más  valor a sus aretes que a la realidad de ríos \
    de sangre, sin aprobar NI UNA SOLA LEY ANTI NARCO. vago. Vago. Vago. Pecado capital. \
    Usted llamó \"Choreco\" mil veces a un ciudadano y ahí no vio la falta. Hipócrita.")
# Out:
# AnalyzerOutput(output=NEG, probas={NEG: 0.974, NEU: 0.020, POS: 0.006})

# %%
analyzer.predict("Al fin terminó la novela de comedia dirigida por el PLN y FA, con la \
    participación del PLP y PUSC. Que clase de payasos!")
# Out:
# AnalyzerOutput(output=NEG, probas={NEG: 0.936, NEU: 0.054, POS: 0.011})

# %%
analyzer.predict("Digno representante de la Asamblea Legislativa peor evaluada de todos \
    los tiempos, llena de payasos, mariguanos y bochincheras")
# Out:
# AnalyzerOutput(output=NEG, probas={NEG: 0.958, NEU: 0.035, POS: 0.007})

# %% [markdown]
# ## Sentiment Analysis
#
# Using **[Comprehend-It](https://rapidapi.com/knowledgator-knowledgator-default/api/comprehend-it/details)** model.
#
# [Original Notebook](https://colab.research.google.com/drive/16WSoq3sp43IQBDvqFxdMFk6UxtukMD74?usp=sharing#scrollTo=t_1sG9BGzT8u)

# %%
import requests
import json

def analyze_sentiment(text):
    url = "https://comprehend-it.p.rapidapi.com/predictions/ml-zero-nli-model"

    # Payload with the text to analyze and the labels for sentiment analysis
    payload = {
        "labels": ["positive", "negative", "neutral"],
        "text": text
    }
    headers = {
        "content-type": "application/json",
        "X-RapidAPI-Key": "API KEY",  # Replace with your API key, refer to documentation for more info.
        "X-RapidAPI-Host": "comprehend-it.p.rapidapi.com"
    }

    # Make the API request
    response = requests.post(url, json=payload, headers=headers)

    # Check if the request was successful
    if response.status_code == 200:
        return response.json()
    else:
        return f"Error: {response.status_code}"

# %%
# Process each text entry and store the results
sentiments = []
for text in data['text']:
    result = analyze_sentiment(text)
    if result:
        # Formatting the sentiment scores as percentages
        sentiment_scores = result['outputs']
        sentiment_str = "; ".join([f"{sent}: {round(score * 100, 2)}%" for sent, score in sentiment_scores.items()])
    else:
        sentiment_str = 'Error'
    sentiments.append(sentiment_str)

# Add the sentiments to the DataFrame
data['Sentiment'] = sentiments
data
